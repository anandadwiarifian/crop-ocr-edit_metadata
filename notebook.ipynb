# %%
from photo_crop import CropBox, CropSize, Position, crop_photos

crop_photos(
    "photos/input",
    "photos/output",
    [
        CropBox.from_position_and_size(
            Position(0, 252), CropSize(1080, 927)
        ),
        CropBox.from_position_and_size(
            Position(0, 1170), CropSize(1080, 909)
        ),
    ]
)
# Out:
# Cropped: Screenshot_20251004_181142_Little Family Room_0.jpg
# Cropped: Screenshot_20251004_181142_Little Family Room_1.jpg
# Cropped: Screenshot_20251004_181046_Little Family Room_0.jpg
# Cropped: Screenshot_20251004_181046_Little Family Room_1.jpg
# Cropped: Screenshot_20251004_181012_Little Family Room_0.jpg
# Cropped: Screenshot_20251004_181012_Little Family Room_1.jpg
# Cropped: Screenshot_20251004_181212_Little Family Room_0.jpg
# Cropped: Screenshot_20251004_181212_Little Family Room_1.jpg
# Cropped: Screenshot_20251004_181106_Little Family Room_0.jpg
# Cropped: Screenshot_20251004_181106_Little Family Room_1.jpg
# Cropped: Screenshot_20251004_181041_Little Family Room_0.jpg
# Cropped: Screenshot_20251004_181041_Little Family Room_1.jpg
# Cropped: Screenshot_20251004_181036_Little Family Room_0.jpg
# Cropped: Screenshot_20251004_181036_Little Family Room_1.jpg
# Cropped: Screenshot_20251004_181130_Little Family Room_0.jpg
# ...

# %%
from edit_photo_dates import batch_set_photo_dates_with_checkout_time

batch_set_photo_dates_with_checkout_time(
    "photos/input/"
)
